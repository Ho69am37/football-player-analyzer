# %%
import json 
import pandas as pd 

with open("../data/competitions.json", "r", encoding = "utf-8") as f:
    competitions = json.load(f)

print(type(competitions))
print(len(competitions))
print(competitions[0])
# Out:
# <class 'list'>
# 80
# {'competition_id': 9, 'season_id': 281, 'country_name': 'Germany', 'competition_name': '1. Bundesliga', 'competition_gender': 'male', 'competition_youth': False, 'competition_international': False, 'season_name': '2023/2024', 'match_updated': '2024-09-28T20:46:38.893391', 'match_updated_360': '2025-11-15T23:17:41.827093', 'match_available_360': '2025-11-15T23:17:41.827093', 'match_available': '2024-09-28T20:46:38.893391'}

# %%
df = pd.DataFrame(competitions)

print("Shape: ", df.shape)
print("\nColumns: ", df.columns.tolist())
print("\nfirst 5 raws: ")
df.head()
# Out:
# Shape:  (80, 12)
#
# Columns:  ['competition_id', 'season_id', 'country_name', 'competition_name', 'competition_gender', 'competition_youth', 'competition_international', 'season_name', 'match_updated', 'match_updated_360', 'match_available_360', 'match_available']
#
# first 5 raws:
#    competition_id  season_id country_name        competition_name  \
# 0               9        281      Germany           1. Bundesliga
# 1               9         27      Germany           1. Bundesliga
# 2            1267        107       Africa  African Cup of Nations
# 3              16          4       Europe        Champions League
# 4              16          1       Europe        Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                       True
# 3               male              False                      False
# 4               male              False                      False
#
#   season_name               match_updated           match_updated_360  \
# 0   2023/2024  2024-09-28T20:46:38.893391  2025-11-15T23:17:41.827093
# 1   2015/2016  2024-05-19T11:11:14.192381                         NaN
# 2        2023  2026-05-12T21:18:08.827431  2026-05-02T02:07:18.902396
# 3   2018/2019  2026-05-15T15:54:04.598614     2021-06-13T16:17:31.694
# 4   2017/2018  2024-02-13T02:35:28.134882     2021-06-13T16:17:31.694
#
#           match_available_360             match_available
# 0  2025-11-15T23:17:41.827093  2024-09-28T20:46:38.893391
# 1                         NaN  2024-05-19T11:11:14.192381
# 2  2026-05-02T02:07:18.902396  2026-05-12T21:18:08.827431
# 3                         NaN  2026-05-15T15:54:04.598614
# 4                         NaN  2024-02-13T02:35:28.134882

# %%
print("Unique Competitions: ", df["competition_name"].nunique())
print("\nAll competitions: ")
print(df["competition_name"].unique())
# Out:
# Unique Competitions:  24
#
# All competitions:
# <StringArray>
# [          '1. Bundesliga',  'African Cup of Nations',
#         'Champions League',            'Copa America',
#             'Copa del Rey', 'FA Women's Super League',
#       'FIFA U20 World Cup',          'FIFA World Cup',
#        'Frauen Bundesliga',     'Indian Super league',
#                  'La Liga',                  'Liga F',
#         'Liga Profesional',                 'Ligue 1',
#      'Major League Soccer',   'North American League',
#                     'NWSL',          'Premier League',
#                  'Serie A',           'Serie A Women',
#                'UEFA Euro',      'UEFA Europa League',
#        'UEFA Women's Euro',       'Women's World Cup']
# Length: 24, dtype: str

# %%
cl =  df[df["competition_name"] == 'Champions League']
print("champions league seasons: ", len(cl))
print("\nAll Champions League seasons:")
print(cl[['competition_id', 'season_id', 'season_name']])
# Out:
# champions league seasons:  18
#
# All Champions League seasons:
#     competition_id  season_id season_name
# 3               16          4   2018/2019
# 4               16          1   2017/2018
# 5               16          2   2016/2017
# 6               16         27   2015/2016
# 7               16         26   2014/2015
# 8               16         25   2013/2014
# 9               16         24   2012/2013
# 10              16         23   2011/2012
# 11              16         22   2010/2011
# 12              16         21   2009/2010
# 13              16         41   2008/2009
# 14              16         39   2006/2007
# 15              16         37   2004/2005
# 16              16         44   2003/2004
# 17              16         76   1999/2000
# 18              16        277   1972/1973
# 19              16         71   1971/1972
# 20              16        276   1970/1971

# %%
import json

with open("../data/matches/16/4.json", "r", encoding="utf-8") as f:
    matches = json.load(f)

print("Type : ", type(matches))
print("\nNumber of matches : ", len(matches))
for m in matches:
    home = m['home_team']['home_team_name']
    away = m['away_team']['away_team_name']
    print(f" {m['match_date']} | {home} vs {away} | match_id: {m['match_id']}")
# Out:
# Type :  <class 'list'>
#
# Number of matches :  1
#  2019-06-01 | Tottenham Hotspur vs Liverpool | match_id: 22912

# %%
match_id = 22912

with open(f"../data/events/{match_id}.json", "r", encoding="utf-8") as f:
    events = json.load(f)

print("Total events: ", len(events))
print("\nfirst Event: ", events[0])
# Out:
# Total events:  3165
#
# first Event:  {'id': '9ec3d009-c15b-4a8d-be80-57a07f40755a', 'index': 1, 'period': 1, 'timestamp': '00:00:00.000', 'minute': 0, 'second': 0, 'type': {'id': 35, 'name': 'Starting XI'}, 'possession': 1, 'possession_team': {'id': 38, 'name': 'Tottenham Hotspur'}, 'play_pattern': {'id': 1, 'name': 'Regular Play'}, 'team': {'id': 38, 'name': 'Tottenham Hotspur'}, 'duration': 0.0, 'tactics': {'formation': 4231, 'lineup': [{'player': {'id': 3099, 'name': 'Hugo Lloris'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'jersey_number': 1}, {'player': {'id': 3308, 'name': 'Kieran Trippier'}, 'position': {'id': 2, 'name': 'Right Back'}, 'jersey_number': 2}, {'player': {'id': 20005, 'name': 'Toby Alderweireld'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'jersey_number': 4}, {'player': {'id': 3077, 'name': 'Jan Vertonghen'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'jersey_number': 5}, {'player': {'id': 3594, 'name': 'Danny Rose'}, 'position': {'id': 6, 'name': 'Left Back'}, 'jersey_number': 3}, {'player': {'id': 3091, 'name': 'Moussa Sissoko'}, 'position': {'id': 9, 'name': 'Right Defensive Midfield'}, 'jersey_number': 17}, {'player': {'id': 3082, 'name': 'Harry Winks'}, 'position': {'id': 15, 'name': 'Left Center Midfield'}, 'jersey_number': 8}, {'player': {'id': 3043, 'name': 'Christian Dannemann Eriksen'}, 'position': {'id': 17, 'name': 'Right Wing'}, 'jersey_number': 23}, {'player': {'id': 3094, 'name': 'Bamidele Alli'}, 'position': {'id': 19, 'name': 'Center Attacking Midfield'}, 'jersey_number': 20}, {'player': {'id': 3083, 'name': 'Heung-Min Son'}, 'position': {'id': 21, 'name': 'Left Wing'}, 'jersey_number': 7}, {'player': {'id': 10955, 'name': 'Harry Kane'}, 'position': {'id': 23, 'name': 'Center Forward'}, 'jersey_number': 10}]}}

# %%
print("=== First event (full structure) ===")
print(json.dumps(events[0], indent=2, ensure_ascii=False))
# Out:
# === First event (full structure) ===
# {
#   "id": "9ec3d009-c15b-4a8d-be80-57a07f40755a",
#   "index": 1,
#   "period": 1,
#   "timestamp": "00:00:00.000",
#   "minute": 0,
#   "second": 0,
#   "type": {
#     "id": 35,
#     "name": "Starting XI"
#   },
#   "possession": 1,
#   "possession_team": {
#     "id": 38,
#     "name": "Tottenham Hotspur"
#   },
#   "play_pattern": {
#     "id": 1,
#     "name": "Regular Play"
#   },
#   "team": {
#     "id": 38,
#     "name": "Tottenham Hotspur"
#   },
#   "duration": 0.0,
#   "tactics": {
#     "formation": 4231,
#     "lineup": [
#       {
#         "player": {
#           "id": 3099,
#           "name": "Hugo Lloris"
#         },
#         "position": {
#           "id": 1,
#           "name": "Goalkeeper"
#         },
#         "jersey_number": 1
#       },
#       {
#         "player": {
#           "id": 3308,
#           "name": "Kieran Trippier"
#         },
#         "position": {
#           "id": 2,
#           "name": "Right Back"
#         },
#         "jersey_number": 2
#       },
#       {
#         "player": {
#           "id": 20005,
#           "name": "Toby Alderweireld"
#         },
#         "position": {
#           "id": 3,
#           "name": "Right Center Back"
#         },
#         "jersey_number": 4
#       },
#       {
#         "player": {
#           "id": 3077,
#           "name": "Jan Vertonghen"
#         },
#         "position": {
#           "id": 5,
#           "name": "Left Center Back"
#         },
#         "jersey_number": 5
#       },
#       {
#         "player": {
#           "id": 3594,
#           "name": "Danny Rose"
#         },
#         "position": {
#           "id": 6,
#           "name": "Left Back"
#         },
#         "jersey_number": 3
#       },
#       {
#         "player": {
#           "id": 3091,
#           "name": "Moussa Sissoko"
#         },
#         "position": {
#           "id": 9,
#           "name": "Right Defensive Midfield"
#         },
#         "jersey_number": 17
#       },
#       {
#         "player": {
#           "id": 3082,
#           "name": "Harry Winks"
#         },
#         "position": {
#           "id": 15,
#           "name": "Left Center Midfield"
#         },
#         "jersey_number": 8
#       },
#       {
#         "player": {
#           "id": 3043,
#           "name": "Christian Dannemann Eriksen"
#         },
#         "position": {
#           "id": 17,
#           "name": "Right Wing"
#         },
#         "jersey_number": 23
#       },
#       {
#         "player": {
#           "id": 3094,
#           "name": "Bamidele Alli"
#         },
#         "position": {
#           "id": 19,
#           "name": "Center Attacking Midfield"
#         },
#         "jersey_number": 20
#       },
#       {
#         "player": {
#           "id": 3083,
#           "name": "Heung-Min Son"
#         },
#         "position": {
#           "id": 21,
#           "name": "Left Wing"
#         },
#         "jersey_number": 7
#       },
#       {
#         "player": {
#           "id": 10955,
#           "name": "Harry Kane"
#         },
#         "position": {
#           "id": 23,
#           "name": "Center Forward"
#         },
#         "jersey_number": 10
#       }
#     ]
#   }
# }

# %%
event_types = {}
for e in events:
    t = e['type']['name']
    event_types[t] = event_types.get(t, 0) + 1

print("=== Event types ===")
for t, count in sorted(event_types.items(), key=lambda x: -x[1]):
    print(f"{t}: {count}")
# Out:
# === Event types ===
# Pass: 890
# Ball Receipt*: 846
# Carry: 669
# Pressure: 314
# Ball Recovery: 100
# Duel: 56
# Clearance: 51
# Goal Keeper: 38
# Shot: 30
# Block: 25
# Miscontrol: 22
# Dispossessed: 19
# Foul Committed: 15
# Interception: 15
# Dribble: 15
# Foul Won: 12
# Dribbled Past: 10
# 50/50: 6
# Substitution: 6
# Shield: 5
# Half Start: 4
# Injury Stoppage: 4
# Half End: 4
# Tactical Shift: 4
# Starting XI: 2
# Referee Ball-Drop: 2
# Offside: 1

# %%
pass_events = [e for e in events if e['type']['name'] == 'Pass']
print("Total passes:", len(pass_events))
print(pass_events[0])
# Out:
# Total passes: 890
# {'id': 'b67ef6a9-e877-4dbe-bb03-edcc9d8c7711', 'index': 5, 'period': 1, 'timestamp': '00:00:00.208', 'minute': 0, 'second': 0, 'type': {'id': 30, 'name': 'Pass'}, 'possession': 2, 'possession_team': {'id': 24, 'name': 'Liverpool'}, 'play_pattern': {'id': 9, 'name': 'From Kick Off'}, 'team': {'id': 24, 'name': 'Liverpool'}, 'player': {'id': 3532, 'name': 'Jordan Brian Henderson'}, 'position': {'id': 13, 'name': 'Right Center Midfield'}, 'location': [61.0, 40.1], 'duration': 1.666205, 'related_events': ['c7297515-ae92-4fb4-93a8-59745b8dfa90'], 'pass': {'recipient': {'id': 3502, 'name': 'Joël Andre Job Matip'}, 'length': 27.252338, 'angle': 3.005404, 'height': {'id': 1, 'name': 'Ground Pass'}, 'end_location': [34.0, 43.8], 'body_part': {'id': 40, 'name': 'Right Foot'}, 'type': {'id': 65, 'name': 'Kick Off'}}}

# %%
players = set()

for e in events:
    if 'player' in e:
        players.add(e['player']['name'])

print(f"total of players : {len(players)}")
print("\nAll players: ")
print(sorted(players))
# Out:
# total of players : 28
#
# All players:
# ['Alisson Ramsés Becker', 'Andrew Robertson', 'Bamidele Alli', 'Christian Dannemann Eriksen', 'Danny Rose', 'Divock Okoth Origi', 'Eric Dier', 'Fernando Llorente Torres', 'Fábio Henrique Tavares', 'Georginio Wijnaldum', 'Harry Kane', 'Harry Winks', 'Heung-Min Son', 'Hugo Lloris', 'James Philip Milner', 'Jan Vertonghen', 'Joe Gomez', 'Jordan Brian Henderson', 'Joël Andre Job Matip', 'Kieran Trippier', 'Lucas Rodrigues Moura da Silva', 'Mohamed Salah', 'Moussa Sissoko', 'Roberto Firmino Barbosa de Oliveira', 'Sadio Mané', 'Toby Alderweireld', 'Trent Alexander-Arnold', 'Virgil van Dijk']

# %%
print(f"Total players: {len(players)}")
print("\n=== All players ===")
for i, p in enumerate(sorted(players), 1):
    print(f"{i:2d}. {p}")
# Out:
# Total players: 28
#
# === All players ===
#  1. Alisson Ramsés Becker
#  2. Andrew Robertson
#  3. Bamidele Alli
#  4. Christian Dannemann Eriksen
#  5. Danny Rose
#  6. Divock Okoth Origi
#  7. Eric Dier
#  8. Fernando Llorente Torres
#  9. Fábio Henrique Tavares
# 10. Georginio Wijnaldum
# 11. Harry Kane
# 12. Harry Winks
# 13. Heung-Min Son
# 14. Hugo Lloris
# 15. James Philip Milner
# 16. Jan Vertonghen
# 17. Joe Gomez
# 18. Jordan Brian Henderson
# 19. Joël Andre Job Matip
# 20. Kieran Trippier
# 21. Lucas Rodrigues Moura da Silva
# 22. Mohamed Salah
# 23. Moussa Sissoko
# 24. Roberto Firmino Barbosa de Oliveira
# 25. Sadio Mané
# 26. Toby Alderweireld
# 27. Trent Alexander-Arnold
# 28. Virgil van Dijk

# %%
def get_player_stats(events, player_name):
    player_events = [e for e in events if e.get('player', {}).get('name') == player_name]
    stats = {
        'total_events': len(player_events),
        'passes': 0,
        'passes_completed': 0,
        'pass_pct': 0.0,
        'shots': 0,
        'goals': 0,
        'carries': 0,
        'pressures': 0,
        'duels': 0,
    }

    for e in player_events:
        t = e['type']['name']

        if t == 'Pass':
            stats['passes'] += 1
            if 'outcome' not in e.get('pass', {}):
                stats['passes_completed'] += 1
        elif t == 'Shot':
            stats['shots'] += 1
            if e.get('shot', {}).get('outcome', {}).get('name', {}) == 'Goal':
                stats['goals'] += 1
        elif t == 'Carry':
            stats['carries'] += 1
        elif t == 'Pressure':
            stats['pressures'] += 1
        elif t == 'Duel':
            stats['duels'] += 1

    if stats['passes'] > 0:
        stats['pass_pct'] = stats['passes_completed'] / stats['passes'] * 100
    return stats

stats = get_player_stats(events, 'Mohamed Salah')
print("===Mohamed Salah===")
for k, v in stats.items():
    print(f" {k}: {v}")
# Out:
# ===Mohamed Salah===
#  total_events: 138
#  passes: 17
#  passes_completed: 7
#  pass_pct: 41.17647058823529
#  shots: 6
#  goals: 1
#  carries: 19
#  pressures: 34
#  duels: 1

# %%
players_to_compare = [
    'Mohamed Salah',
    'Sadio Mané',
    'Roberto Firmino',   
    'Harry Kane',
    'Heung-Min Son',
    'Christian Dannemann Eriksen',
]

for p in players_to_compare:
    stats = get_player_stats(events, p)
    if stats['total_events'] == 0:
        print(f"\n {p} not found!")
        continue
    
    print(f"\n==={p}===")
    print(f" Events: {stats['total_events']}")
    print(f"  Passes: {stats['passes_completed']}/{stats['passes']} ({stats['pass_pct']:.1f}%)")
    print(f"  Shots: {stats['shots']} | Goals: {stats['goals']}")
    print(f"  Carries: {stats['carries']}")
    print(f"  Pressures: {stats['pressures']}")
# Out:
# ===Mohamed Salah===
#  Events: 138
#   Passes: 7/17 (41.2%)
#   Shots: 6 | Goals: 1
#   Carries: 19
#   Pressures: 34
#
# ===Sadio Mané===
#  Events: 140
#   Passes: 18/24 (75.0%)
#   Shots: 0 | Goals: 0
#   Carries: 28
#   Pressures: 24
#
#  Roberto Firmino not found!
#
# ===Harry Kane===
#  Events: 102
#   Passes: 9/15 (60.0%)
#   Shots: 1 | Goals: 0
#   Carries: 18
#   Pressures: 6
#
# ===Heung-Min Son===
#  Events: 142
#   Passes: 18/26 (69.2%)
#   Shots: 3 | Goals: 0
#   Carries: 29
#   Pressures: 10
#
# ===Christian Dannemann Eriksen===
#  Events: 156
#   Passes: 35/45 (77.8%)
#   Shots: 3 | Goals: 0
#   Carries: 45
#   Pressures: 3

# %%
import pandas as pd

all_players_stats = []

for player_name in sorted(players):
    stats = get_player_stats(events, player_name)
    stats['player'] = player_name
    all_players_stats.append(stats)

players_df = pd.DataFrame(all_players_stats)
cols = ['player', 'total_events', 'passes', 'passes_completed', 'pass_pct', 
        'shots', 'goals', 'carries', 'pressures', 'duels']
players_df = players_df[cols]
print("Shape : ", players_df.shape)
print("\n===Top 10 most active players ===")
print(players_df.sort_values('total_events', ascending= False).head(10).to_string(index=False))
# Out:
# Shape :  (28, 10)
#
# ===Top 10 most active players ===
#                      player  total_events  passes  passes_completed  pass_pct  shots  goals  carries  pressures  duels
#              Jan Vertonghen           229      78                67 85.897436      1      0       63          5      1
#           Toby Alderweireld           213      76                60 78.947368      0      0       58          3      1
#             Kieran Trippier           181      77                57 74.025974      0      0       41          4      2
#                 Hugo Lloris           165      60                48 80.000000      0      0       40          0      0
# Christian Dannemann Eriksen           156      45                35 77.777778      3      0       45          3      1
#               Bamidele Alli           153      36                28 77.777778      3      0       33         12      3
#                  Danny Rose           153      49                44 89.795918      2      0       39          4      2
#                 Harry Winks           147      49                39 79.591837      0      0       38          7      2
#               Heung-Min Son           142      26                18 69.230769      3      0       29         10      3
#            Andrew Robertson           140      54                34 62.962963      1      0       29         12      2

# %%
print("=== top 10 Pass Accuracy(Min 20 passes) ===")
good_passer = players_df[players_df['passes'] >= 20].sort_values('pass_pct', ascending= False)
print(good_passer[['player', 'passes', 'passes_completed', 'pass_pct']].head(10).to_string(index= False))
# Out:
# === top 10 Pass Accuracy(Min 20 passes) ===
#                      player  passes  passes_completed  pass_pct
#                  Danny Rose      49                44 89.795918
#              Jan Vertonghen      78                67 85.897436
#              Moussa Sissoko      34                29 85.294118
#                 Hugo Lloris      60                48 80.000000
#                 Harry Winks      49                39 79.591837
#           Toby Alderweireld      76                60 78.947368
#             Virgil van Dijk      32                25 78.125000
#               Bamidele Alli      36                28 77.777778
# Christian Dannemann Eriksen      45                35 77.777778
#                  Sadio Mané      24                18 75.000000

# %%
print("=== Top scorers ===")
scorers = players_df[players_df['shots'] > 0].sort_values('shots', ascending=False)
print(scorers[['player', 'shots', 'goals']].to_string(index= False))

print("\n=== Top 10 Carriers ===")
print(players_df.sort_values('carries', ascending=False).head(10)[['player', 'carries', 'pressures']].to_string(index=False))

print("\n=== Top 10 Pressers ===")
print(players_df.sort_values('pressures', ascending=False).head(10)[['player', 'pressures', 'duels']].to_string(index=False))
# Out:
# === Top scorers ===
#                         player  shots  goals
#                  Mohamed Salah      6      1
#                  Bamidele Alli      3      0
#                  Heung-Min Son      3      0
#    Christian Dannemann Eriksen      3      0
# Lucas Rodrigues Moura da Silva      2      0
#         Jordan Brian Henderson      2      0
#                     Danny Rose      2      0
#               Andrew Robertson      1      0
#                     Harry Kane      1      0
#         Fábio Henrique Tavares      1      0
#             Divock Okoth Origi      1      1
#                 Jan Vertonghen      1      0
#            James Philip Milner      1      0
#                 Moussa Sissoko      1      0
#         Trent Alexander-Arnold      1      0
#                Virgil van Dijk      1      0
#
# === Top 10 Carriers ===
#                      player  carries  pressures
#              Jan Vertonghen       63          5
#           Toby Alderweireld       58          3
# Christian Dannemann Eriksen       45          3
#             Kieran Trippier       41          4
#                 Hugo Lloris       40          0
#                  Danny Rose       39          4
#                 Harry Winks       38          7
#               Bamidele Alli       33         12
#              Moussa Sissoko       31          6
#            Andrew Robertson       29         12
#
# === Top 10 Pressers ===
#                              player  pressures  duels
#                       Mohamed Salah         34      1
# Roberto Firmino Barbosa de Oliveira         30      2
#              Fábio Henrique Tavares         29      3
#              Jordan Brian Henderson         29      4
#                          Sadio Mané         24      3
#                 Georginio Wijnaldum         21      0
#                  Divock Okoth Origi         20      1
#              Trent Alexander-Arnold         18      3
#                Joël Andre Job Matip         14      3
#                    Andrew Robertson         12      2
